# %% [markdown]
# <a href="https://colab.research.google.com/github/nonikf/Project-Algoritma-Pemrograman-Kelompok-B-Kelas-A/blob/main/Program_5_Project_ALPRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Skenario 1

# %%
import math

# titik pusat cluster
A = (2, 1, 3)
B = (1, -4, 6)
C = (-2, 3, -2)

# input titik U
x1 = float(input("Masukkan x1: "))
x2 = float(input("Masukkan x2: "))
x3 = float(input("Masukkan x3: "))

U = (x1, x2, x3)

# fungsi jarak
def jarak(P, Q):
    return math.sqrt((P[0]-Q[0])**2 + (P[1]-Q[1])**2 + (P[2]-Q[2])**2)

# hitung jarak
dA = jarak(U, A)
dB = jarak(U, B)
dC = jarak(U, C)

# tampilkan jarak
print("Jarak ke A:", dA)
print("Jarak ke B:", dB)
print("Jarak ke C:", dC)

# menentukan cluster
if dA <= dB and dA <= dC:
    print("Titik U masuk cluster A")
elif dB <= dA and dB <= dC:
    print("Titik U masuk cluster B")
else:
    print("Titik U masuk cluster C")
# Out:
# Masukkan x1: 4
# Masukkan x2: -1
# Masukkan x3: 2
# Jarak ke A: 3.0
# Jarak ke B: 5.830951894845301
# Jarak ke C: 8.246211251235321
# Titik U masuk cluster A

# %% [markdown]
# #Skenario 2

# %%
import math

# titik pusat cluster
A = (2, 1, 3)
B = (1, -4, 6)
C = (-2, 3, -2)

# input titik U
x1 = float(input("Masukkan x1: "))
x2 = float(input("Masukkan x2: "))
x3 = float(input("Masukkan x3: "))

U = (x1, x2, x3)

# fungsi jarak
def jarak(P, Q):
    return math.sqrt((P[0]-Q[0])**2 + (P[1]-Q[1])**2 + (P[2]-Q[2])**2)

# hitung jarak
dA = jarak(U, A)
dB = jarak(U, B)
dC = jarak(U, C)

# tampilkan jarak
print("Jarak ke A:", dA)
print("Jarak ke B:", dB)
print("Jarak ke C:", dC)

# menentukan cluster
if dA <= dB and dA <= dC:
    print("Titik U masuk cluster A")
elif dB <= dA and dB <= dC:
    print("Titik U masuk cluster B")
else:
    print("Titik U masuk cluster C")
# Out:
# Masukkan x1: 2
# Masukkan x2: -6
# Masukkan x3: 5
# Jarak ke A: 7.280109889280518
# Jarak ke B: 2.449489742783178
# Jarak ke C: 12.083045973594572
# Titik U masuk cluster B

# %% [markdown]
# #Skenario 3

# %%
import math

# titik pusat cluster
A = (2, 1, 3)
B = (1, -4, 6)
C = (-2, 3, -2)

# input titik U
x1 = float(input("Masukkan x1: "))
x2 = float(input("Masukkan x2: "))
x3 = float(input("Masukkan x3: "))

U = (x1, x2, x3)

# fungsi jarak
def jarak(P, Q):
    return math.sqrt((P[0]-Q[0])**2 + (P[1]-Q[1])**2 + (P[2]-Q[2])**2)

# hitung jarak
dA = jarak(U, A)
dB = jarak(U, B)
dC = jarak(U, C)

# tampilkan jarak
print("Jarak ke A:", dA)
print("Jarak ke B:", dB)
print("Jarak ke C:", dC)

# menentukan cluster
if dA <= dB and dA <= dC:
    print("Titik U masuk cluster A")
elif dB <= dA and dB <= dC:
    print("Titik U masuk cluster B")
else:
    print("Titik U masuk cluster C")
# Out:
# Masukkan x1: 0
# Masukkan x2: 4
# Masukkan x3: -1
# Jarak ke A: 5.385164807134504
# Jarak ke B: 10.677078252031311
# Jarak ke C: 2.449489742783178
# Titik U masuk cluster C
